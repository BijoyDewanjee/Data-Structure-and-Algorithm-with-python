# %% [markdown]
# 🧾 Steps of Linear Search Algorithm
#
# 1️⃣ Array-এর প্রথম element থেকে search শুরু করো।
#
# 2️⃣ Current element-এর সাথে key compare করো।
#
# 3️⃣ যদি element == key হয়, তাহলে
#     👉 element-এর index return করো এবং search বন্ধ করো।
#
# 4️⃣ যদি element != key হয়, তাহলে
#     👉 পরের element-এ যাও।
#
# 5️⃣ Array-এর শেষ পর্যন্ত গিয়েও যদি key না পাওয়া যায়,
#     👉 -1 return করো।

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i   
    return -1    
    
          
arr = [5, 2, 9, 1, 7]
target = 1

print(linear_search(arr, target))
# Out:
# 3
